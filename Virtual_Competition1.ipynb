# %% [markdown]
# Consider the following Python dictionary data and Python list labels:
#
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %% [markdown]
# # 1. Create a DataFrame df from this dictionary data which has the index labels.

# %%
import numpy as np
import pandas as pd

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df = pd.DataFrame(data, index=labels)

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# # 2. Display a summary of the basic information about this DataFrame and its data (hint: there is a single method that can be called on the DataFrame).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %% [markdown]
# # 3. Return the first 3 rows of the DataFrame df.

# %%
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# # 4. Display the 'animal' and 'age' columns from the DataFrame df

# %%
print(df[["animal", "age"]])
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# # 5. Display the data in rows [3, 4, 8] and in columns `['animal', 'age']'

# %%
print(df.iloc[[3, 4, 8], [0, 1]])
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# # 6. Select only the rows where the number of visits is greater than 3.

# %%
threevisit = df[df["visits"] > 3]
print(threevisit)
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %% [markdown]
# # 7. Select the rows where the age is missing, i.e. it is NaN.

# %%
age = df[df["age"].isna()]
print(age)
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# # 8. Select the rows where the animal is a cat and the age is less than 3.

# %%
threeless = df[(df["age"] < 3) & (df["animal"] == "cat")]
print(threeless)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %% [markdown]
# # 9. Select the rows where the age is between 2 and 4 (inclusive)

# %%
twoage = df[(df["age"] >= 2) & (df["age"] <= 4)]
print(twoage)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# # 10. Change the age in row 'f' to 1.5.

# %%
df.loc['f', 'age'] = 1.5

# %%
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# # 11. Calculate the sum of all visits in df (i.e. the total number of visits).

# %%
total_visits = df["visits"].sum()

print(total_visits)
# Out:
# 19

# %% [markdown]
# # 12. Calculate the mean age for each different animal in df.

# %%
# Calculate the mean age for each animal
animal_age_means = df.groupby("animal")["age"].mean()

# Print the mean age for each animal
print(animal_age_means)
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# # 13. Append a new row 'k' to df with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
# Append a new row 'k' with your choice of values
df.loc['k'] = ["panda", 15,3,"no"]

# Print the DataFrame with the new row
print(df)
# Out:
#   animal   age  visits priority
# a    cat   2.5       1      yes
# b    cat   3.0       3      yes
# c  snake   0.5       2       no
# d    dog   NaN       3      yes
# e    dog   5.0       2       no
# f    cat   1.5       3       no
# g  snake   4.5       1       no
# h    cat   NaN       1      yes
# i    dog   7.0       2       no
# j    dog   3.0       1       no
# k  panda  15.0       3       no

# %%
# Delete the new row
df = df.drop('k')

# Print the original DataFrame
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# # 14. Count the number of each type of animal in df.

# %%
count = df.groupby("animal")["animal"].count()
print(count)
# Out:
# animal
# cat      4
# dog      4
# snake    2
# Name: animal, dtype: int64

# %%
# Count the number of each type of animal
animal_counts = df["animal"].value_counts()

# Print the number of each type of animal
print(animal_counts)
# Out:
# cat      4
# dog      4
# snake    2
# Name: animal, dtype: int64

# %% [markdown]
# # 15. Sort df first by the values in the 'age' in decending order, then by the value in the 'visits' column in ascending order (so row i should be first, and row d should be last).

# %%
# Sort df by the values in the 'age' in decending order, then by the value in the 'visits' column in ascending order
df = df.sort_values(by=["age", "visits"], ascending=[False, True])

# Print the sorted DataFrame
print(df)
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  1.5       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# # 16. The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be True and 'no' should be False.

# %%
# Replace the 'priority' column with a column of boolean values
df["priority"] = df["priority"].replace({"yes": True, "no": False})

# Print the DataFrame
print(df)
# Out:
#   animal  age  visits  priority
# i    dog  7.0       2     False
# e    dog  5.0       2     False
# g  snake  4.5       1     False
# j    dog  3.0       1     False
# b    cat  3.0       3      True
# a    cat  2.5       1      True
# f    cat  1.5       3     False
# c  snake  0.5       2     False
# h    cat  NaN       1      True
# d    dog  NaN       3      True

# %% [markdown]
# # 17. In the 'animal' column, change the 'snake' entries to 'python'.

# %%
df["animal"] = df["animal"].replace({"snake": "python"})
# Print the DataFrame
print(df)
# Out:
#    animal  age  visits  priority
# i     dog  7.0       2     False
# e     dog  5.0       2     False
# g  python  4.5       1     False
# j     dog  3.0       1     False
# b     cat  3.0       3      True
# a     cat  2.5       1      True
# f     cat  1.5       3     False
# c  python  0.5       2     False
# h     cat  NaN       1      True
# d     dog  NaN       3      True

# %% [markdown]
# # 18. Load the ny-flights dataset to Python

# %%
#load the dataset
df=pd.read_csv('/Users/nidhi.anil/Downloads/ny-flights.csv')

# %%
df.head()
# Out:
#                fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0  2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1  2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2  2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3  2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4  2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
#
#   dest  dep_time  dep_delay  arr_time  arr_delay  cancelled  \
# 0  LAX     914.0       14.0    1238.0       13.0        0.0
# 1  LAX    1157.0       -3.0    1523.0       13.0        0.0
# 2  LAX    1902.0        2.0    2224.0        9.0        0.0
# 3  PBI     722.0       -8.0    1014.0      -26.0        0.0
# 4  LAX    1347.0        2.0    1706.0        1.0        0.0
#
#                    arr                  dep
# 0  2014-01-01 12:38:00  2014-01-01 09:14:00
# 1  2014-01-01 15:23:00  2014-01-01 11:57:00
# ...

# %% [markdown]
# # 19. Which airline ID is present maximum times in the dataset

# %%
# Count the number of times each airline ID appears in the dataset
airline_id_counts = df["airline_id"].value_counts()

# %%
# Find the airline ID with the maximum number of appearances
max_airline_id = airline_id_counts.sort_values(ascending=False).index[0]

# Print the airline ID with the maximum number of appearances
print(max_airline_id)
# Out:
# 20409

# %% [markdown]
# # 20. Draw a plot between dep_delay and arr_delay

# %%
import matplotlib.pyplot as plt


# Plot the dep_delay vs arr_delay
plt.figure(figsize=(30,20))

plt.plot(df["dep_delay"], df["arr_delay"],"+",alpha=0.2)


# Add a title and labels to the axes
plt.title("Departure Delay vs. Arrival Delay")
plt.xlabel("Departure Delay (minutes)")
plt.ylabel("Arrival Delay (minutes)")

# Show the plot
plt.show()
